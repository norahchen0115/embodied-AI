# %% [markdown]
# 👾学习路线
# ---
#
# | 优先级   | 学习内容              | 推荐资源                         |
# | ----- | ----------------- | ---------------------------- |
# | ⭐⭐⭐⭐⭐ | 机器人学习整体框架         | Hugging Face Robotics Course [HF 教程](https://huggingface.co/learn/robotics-course/)|
# | ⭐⭐⭐⭐⭐ | LeRobot 实战        | LeRobot 官方教程 [LeRobot 官方教程](https://docs.swanlab.cn/en/examples/robot/lerobot-guide.html)|
# | ⭐⭐⭐⭐⭐ | 仿真平台              | ManiSkill Documentation, RoboTwin2.0  [ManiSkill 仿真平台](https://maniskill.readthedocs.io/en/latest/user_guide/index.html?utm_source=chatgpt.com)  [DP_policy](https://diffusion-policy.cs.columbia.edu/)   [RoboTwin2.0](https://github.com/RoboTwin-Platform/RoboTwin)|
# | ⭐⭐⭐⭐☆ | VLA 模型            | OpenVLA                      |
# | ⭐⭐⭐⭐☆ | Robot Learning 理论 | Robot Learning: A Tutorial   |
# | ⭐⭐⭐☆☆ | 机器人学基础            | Modern Robotics              |
# | ⭐⭐☆☆☆ | ROS2              | 后续按需学习                       |
